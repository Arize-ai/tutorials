# %% [markdown]
# <center>
#     <p style="text-align:center">
#     <img alt="arize logo" src="https://storage.googleapis.com/arize-assets/arize-logo-white.jpg" width="300"/>
#         <br>
#         <a href="https://docs.arize.com/arize/">Docs</a>
#         |
#         <a href="https://github.com/Arize-ai/client_python">GitHub</a>
#         |
#         <a href="https://join.slack.com/t/arize-ai/shared_invite/zt-1px8dcmlf-fmThhDFD_V_48oU7ALan4Q">Community</a>
#     </p>
# </center>
#
# <center><h1>Using Arize with RAG</h1></center>
#
# This guide shows you how to create a retrieval augmented generation chatbot and evaluate performance with Arize. RAG is typically to respond to queries using a specified set of documents instead of using the LLM's own training data, reducing hallucination and incorrect generations.
#
# We'll go through the following steps:
#
# * Create a RAG chatbot using LlamaIndex
#
# * Trace the retrieval and llm calls using Arize
#
# * Create a dataset to benchmark performance
#
# * Evaluate performance using LLM as a judge

# %% [markdown]
# # Create a RAG chatbot using LlamaIndex
#
# Let's start with all of our boilerplate setup:
#
# 1. Install packages for tracing and retrieval
# 2. Setup our API keys
# 3. Setup Phoenix for tracing
# 4. Create our LlamaIndex query engine
# 5. See your results in Phoenix

# %% [markdown]
# ### Install packages for tracing and retrieval

# %%
# !pip install llama-index openai arize-phoenix-evals arize-otel openinference-instrumentation-llama-index
# Out:
# Collecting llama-index
#   Using cached llama_index-0.11.22-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.52.2)
# Collecting arize-phoenix-evals
#   Using cached arize_phoenix_evals-0.17.3-py3-none-any.whl.metadata (4.3 kB)
# Collecting arize-otel
#   Using cached arize_otel-0.5.3-py3-none-any.whl.metadata (11 kB)
# Collecting openinference-instrumentation-llama-index
#   Using cached openinference_instrumentation_llama_index-3.0.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting llama-index-agent-openai<0.4.0,>=0.3.4 (from llama-index)
#   Using cached llama_index_agent_openai-0.3.4-py3-none-any.whl.metadata (728 bytes)
# Collecting llama-index-cli<0.4.0,>=0.3.1 (from llama-index)
#   Using cached llama_index_cli-0.3.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting llama-index-core<0.12.0,>=0.11.22 (from llama-index)
#   Using cached llama_index_core-0.11.22-py3-none-any.whl.metadata (2.4 kB)
# Collecting llama-index-embeddings-openai<0.3.0,>=0.2.4 (from llama-index)
#   Using cached llama_index_embeddings_openai-0.2.5-py3-none-any.whl.metadata (686 bytes)
# Collecting llama-index-indices-managed-llama-cloud>=0.3.0 (from llama-index)
#   Using cached llama_index_indices_managed_llama_cloud-0.4.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting llama-index-legacy<0.10.0,>=0.9.48 (from llama-index)
#   Using cached llama_index_legacy-0.9.48.post4-py3-none-any.whl.metadata (8.5 kB)
# Collecting llama-index-llms-openai<0.3.0,>=0.2.10 (from llama-index)
#   Using cached llama_index_llms_openai-0.2.16-py3-none-any.whl.metadata (3.3 kB)
# Collecting llama-index-multi-modal-llms-openai<0.3.0,>=0.2.0 (from llama-index)
#   Using cached llama_index_multi_modal_llms_openai-0.2.3-py3-none-any.whl.metadata (729 bytes)
# Collecting llama-index-program-openai<0.3.0,>=0.2.0 (from llama-index)
#   Using cached llama_index_program_openai-0.2.0-py3-none-any.whl.metadata (766 bytes)
# Collecting llama-index-question-gen-openai<0.3.0,>=0.2.0 (from llama-index)
#   Using cached llama_index_question_gen_openai-0.2.0-py3-none-any.whl.metadata (785 bytes)
# Collecting llama-index-readers-file<0.3.0,>=0.2.0 (from llama-index)
#   Using cached llama_index_readers_file-0.2.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting llama-index-readers-llama-parse>=0.3.0 (from llama-index)
#   Using cached llama_index_readers_llama_parse-0.3.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting nltk>3.8.1 (from llama-index)
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.6.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from arize-phoenix-evals) (2.2.2)
# Collecting openinference-semantic-conventions>=0.1.5 (from arize-otel)
#   Using cached openinference_semantic_conventions-0.1.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting opentelemetry-exporter-otlp>=1.22 (from arize-otel)
#   Using cached opentelemetry_exporter_otlp-1.28.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-proto>=1.12.0 (from arize-otel)
#   Using cached opentelemetry_proto-1.28.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk>=1.22 (from arize-otel)
#   Using cached opentelemetry_sdk-1.28.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting openinference-instrumentation>=0.1.17 (from openinference-instrumentation-llama-index)
#   Using cached openinference_instrumentation-0.1.18-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: opentelemetry-api in /usr/local/lib/python3.10/dist-packages (from openinference-instrumentation-llama-index) (1.16.0)
# Collecting opentelemetry-instrumentation (from openinference-instrumentation-llama-index)
#   Using cached opentelemetry_instrumentation-0.49b0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: opentelemetry-semantic-conventions in /usr/local/lib/python3.10/dist-packages (from openinference-instrumentation-llama-index) (0.37b0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from openinference-instrumentation-llama-index) (1.16.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.22->llama-index) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.22->llama-index) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.22->llama-index) (3.10.10)
# Collecting dataclasses-json (from llama-index-core<0.12.0,>=0.11.22->llama-index)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.22->llama-index) (1.2.14)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core<0.12.0,>=0.11.22->llama-index)
#   Using cached dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.22->llama-index) (2024.10.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.22->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.22->llama-index) (3.4.2)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.22->llama-index) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.22->llama-index) (10.4.0)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.12.0,>=0.11.22->llama-index) (2.32.3)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.2.0 (from llama-index-core<0.12.0,>=0.11.22->llama-index)
#   Using cached tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting tiktoken>=0.3.3 (from llama-index-core<0.12.0,>=0.11.22->llama-index)
#   Using cached tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting typing-inspect>=0.8.0 (from llama-index-core<0.12.0,>=0.11.22->llama-index)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting llama-cloud>=0.0.11 (from llama-index-indices-managed-llama-cloud>=0.3.0->llama-index)
#   Using cached llama_cloud-0.1.4-py3-none-any.whl.metadata (814 bytes)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (4.12.3)
# Collecting pypdf<5.0.0,>=4.0.1 (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index)
#   Using cached pypdf-4.3.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index)
#   Using cached striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Collecting llama-parse>=0.5.0 (from llama-index-readers-llama-parse>=0.3.0->llama-index)
#   Using cached llama_parse-0.5.13-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index) (2024.9.11)
# Collecting opentelemetry-exporter-otlp-proto-grpc==1.28.0 (from opentelemetry-exporter-otlp>=1.22->arize-otel)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.28.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-exporter-otlp-proto-http==1.28.0 (from opentelemetry-exporter-otlp>=1.22->arize-otel)
#   Using cached opentelemetry_exporter_otlp_proto_http-1.28.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.28.0->opentelemetry-exporter-otlp>=1.22->arize-otel) (1.65.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.28.0->opentelemetry-exporter-otlp>=1.22->arize-otel) (1.64.1)
# Collecting opentelemetry-exporter-otlp-proto-common==1.28.0 (from opentelemetry-exporter-otlp-proto-grpc==1.28.0->opentelemetry-exporter-otlp>=1.22->arize-otel)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.28.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting protobuf<6.0,>=5.0 (from opentelemetry-proto>=1.12.0->arize-otel)
#   Downloading protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api->openinference-instrumentation-llama-index) (75.1.0)
# Collecting opentelemetry-api (from openinference-instrumentation-llama-index)
#   Downloading opentelemetry_api-1.28.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-semantic-conventions (from openinference-instrumentation-llama-index)
#   Downloading opentelemetry_semantic_conventions-0.49b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api->openinference-instrumentation-llama-index) (8.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Requirement already satisfied: packaging>=18.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation->openinference-instrumentation-llama-index) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->arize-phoenix-evals) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->arize-phoenix-evals) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->arize-phoenix-evals) (2024.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->llama-index) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->llama-index) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->llama-index) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->llama-index) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->llama-index) (1.17.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->llama-index) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (2.6)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api->openinference-instrumentation-llama-index) (3.20.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->arize-phoenix-evals) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.22->llama-index) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.22->llama-index) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.22->llama-index) (3.1.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.22->llama-index)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->llama-index-core<0.12.0,>=0.11.22->llama-index)
#   Downloading marshmallow-3.23.1-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->llama-index) (0.2.0)
# Downloading llama_index-0.11.22-py3-none-any.whl (6.8 kB)
# Downloading arize_phoenix_evals-0.17.3-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 2.0 MB/s eta 0:00:00
# Downloading arize_otel-0.5.3-py3-none-any.whl (9.2 kB)
# Downloading openinference_instrumentation_llama_index-3.0.3-py3-none-any.whl (25 kB)
# Downloading llama_index_agent_openai-0.3.4-py3-none-any.whl (13 kB)
# Downloading llama_index_cli-0.3.1-py3-none-any.whl (27 kB)
# Downloading llama_index_core-0.11.22-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.5 MB/s eta 0:00:00
# Downloading llama_index_embeddings_openai-0.2.5-py3-none-any.whl (6.1 kB)
# Downloading llama_index_indices_managed_llama_cloud-0.4.0-py3-none-any.whl (10 kB)
# Downloading llama_index_legacy-0.9.48.post4-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 47.9 MB/s eta 0:00:00
# Downloading llama_index_llms_openai-0.2.16-py3-none-any.whl (13 kB)
# Downloading llama_index_multi_modal_llms_openai-0.2.3-py3-none-any.whl (5.9 kB)
# Downloading llama_index_program_openai-0.2.0-py3-none-any.whl (5.3 kB)
# Downloading llama_index_question_gen_openai-0.2.0-py3-none-any.whl (2.9 kB)
# Downloading llama_index_readers_file-0.2.2-py3-none-any.whl (38 kB)
# Downloading llama_index_readers_llama_parse-0.3.0-py3-none-any.whl (2.5 kB)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 41.6 MB/s eta 0:00:00
# Downloading openinference_instrumentation-0.1.18-py3-none-any.whl (14 kB)
# Downloading openinference_semantic_conventions-0.1.12-py3-none-any.whl (9.1 kB)
# Downloading opentelemetry_exporter_otlp-1.28.0-py3-none-any.whl (7.0 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.28.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.28.0-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 3.5 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_http-1.28.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.28.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_sdk-1.28.0-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 7.0 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.28.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 3.0 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.49b0-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.2/159.2 kB 10.1 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation-0.49b0-py3-none-any.whl (30 kB)
# Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Downloading llama_cloud-0.1.4-py3-none-any.whl (176 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.8/176.8 kB 12.7 MB/s eta 0:00:00
# Downloading llama_parse-0.5.13-py3-none-any.whl (13 kB)
# Downloading protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.6/316.6 kB 20.2 MB/s eta 0:00:00
# Downloading pypdf-4.3.1-py3-none-any.whl (295 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 kB 17.5 MB/s eta 0:00:00
# Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 51.4 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading marshmallow-3.23.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.2 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: striprtf, dirtyjson, tenacity, pypdf, protobuf, openinference-semantic-conventions, nltk, mypy-extensions, marshmallow, typing-inspect, tiktoken, opentelemetry-proto, opentelemetry-api, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, llama-cloud, dataclasses-json, arize-phoenix-evals, opentelemetry-sdk, opentelemetry-instrumentation, llama-index-legacy, llama-index-core, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, openinference-instrumentation, llama-parse, llama-index-readers-file, llama-index-llms-openai, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, opentelemetry-exporter-otlp, openinference-instrumentation-llama-index, llama-index-readers-llama-parse, llama-index-multi-modal-llms-openai, llama-index-cli, llama-index-agent-openai, llama-index-program-openai, arize-otel, llama-index-question-gen-openai, llama-index
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.8.1
#     Uninstalling nltk-3.8.1:
#       Successfully uninstalled nltk-3.8.1
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.16.0
#     Uninstalling opentelemetry-api-1.16.0:
#       Successfully uninstalled opentelemetry-api-1.16.0
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.37b0
#     Uninstalling opentelemetry-semantic-conventions-0.37b0:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.37b0
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.16.0
#     Uninstalling opentelemetry-sdk-1.16.0:
#       Successfully uninstalled opentelemetry-sdk-1.16.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-datastore 2.19.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.28.3 which is incompatible.
# google-cloud-firestore 2.16.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.28.3 which is incompatible.
# tensorboard 2.17.0 requires protobuf!=4.24.0,<5.0.0,>=3.19.6, but you have protobuf 5.28.3 which is incompatible.
# tensorflow 2.17.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.28.3 which is incompatible.
# tensorflow-metadata 1.16.1 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 5.28.3 which is incompatible.
# Successfully installed arize-otel-0.5.3 arize-phoenix-evals-0.17.3 dataclasses-json-0.6.7 dirtyjson-1.0.8 llama-cloud-0.1.4 llama-index-0.11.22 llama-index-agent-openai-0.3.4 llama-index-cli-0.3.1 llama-index-core-0.11.22 llama-index-embeddings-openai-0.2.5 llama-index-indices-managed-llama-cloud-0.4.0 llama-index-legacy-0.9.48.post4 llama-index-llms-openai-0.2.16 llama-index-multi-modal-llms-openai-0.2.3 llama-index-program-openai-0.2.0 llama-index-question-gen-openai-0.2.0 llama-index-readers-file-0.2.2 llama-index-readers-llama-parse-0.3.0 llama-parse-0.5.13 marshmallow-3.23.1 mypy-extensions-1.0.0 nltk-3.9.1 openinference-instrumentation-0.1.18 openinference-instrumentation-llama-index-3.0.3 openinference-semantic-conventions-0.1.12 opentelemetry-api-1.28.0 opentelemetry-exporter-otlp-1.28.0 opentelemetry-exporter-otlp-proto-common-1.28.0 opentelemetry-exporter-otlp-proto-grpc-1.28.0 opentelemetry-exporter-otlp-proto-http-1.28.0 opentelemetry-instrumentation-0.49b0 opentelemetry-proto-1.28.0 opentelemetry-sdk-1.28.0 opentelemetry-semantic-conventions-0.49b0 protobuf-5.28.3 pypdf-4.3.1 striprtf-0.0.26 tenacity-8.5.0 tiktoken-0.8.0 typing-inspect-0.9.0

# %% [markdown]
# ### Setup our API Keys

# %%
import os
from getpass import getpass

if not (openai_api_key := os.getenv("OPENAI_API_KEY")):
    openai_api_key = getpass("🔑 Enter your OpenAI API key: ")

os.environ["OPENAI_API_KEY"] = openai_api_key
# Out:
# 🔑 Enter your OpenAI API key: ··········

# %% [markdown]
# ### Setup Arize for Tracing
#
# To follow with this tutorial, you'll need to sign up for Arize and get your API key. You can see the [guide here](https://docs.arize.com/arize/llm-tracing/quickstart-llm).

# %%
# Import open-telemetry dependencies
from arize_otel import register_otel, Endpoints
from openinference.instrumentation.llama_index import LlamaIndexInstrumentor

# Setup OTEL via our convenience function
register_otel(
    endpoints = Endpoints.ARIZE,
    space_id = getpass("🔑 Enter your Arize Space ID: "),
    api_key = getpass("🔑 Enter your Arize API key: "),
    model_id = "agents-cookbook", # name this to whatever you would like
)
LlamaIndexInstrumentor().instrument()
# Out:
# WARNING:opentelemetry.trace:Overriding of current TracerProvider is not allowed

# %% [markdown]
# ### Create our LlamaIndex query engine

# %%
# !mkdir data
# !wget "https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/paul_graham/paul_graham_essay.txt" -O data/paul_graham_essay.txt
# Out:
# --2024-11-07 19:58:52--  https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/paul_graham/paul_graham_essay.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75042 (73K) [text/plain]
# Saving to: ‘data/paul_graham_essay.txt’
#
# data/paul_graham_es 100%[===================>]  73.28K  --.-KB/s    in 0.1s
#
# 2024-11-07 19:58:53 (726 KB/s) - ‘data/paul_graham_essay.txt’ saved [75042/75042]

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from pprint import pprint

# load documents
documents = SimpleDirectoryReader("data").load_data()
index = VectorStoreIndex.from_documents(documents)
query_engine = index.as_query_engine()
response = query_engine.query("What did Paul Graham work on?")
pprint(response)
# Out:
# Response(response='Paul Graham worked on various projects such as painting, '
#                   'experimenting with a new kind of still life, looking for an '
#                   'apartment to buy, starting a web app for making web apps, '
#                   'working on an application builder, developing a new dialect '
#                   'of Lisp called Arc, writing essays, working on spam '
#                   'filters, hosting dinners for friends, and starting an '
#                   'investment firm called Y Combinator.',
#          source_nodes=[NodeWithScore(node=TextNode(id_='44a9caee-a671-4859-80d9-78a2aee6063d', embedding=None, metadata={'file_path': '/content/data/paul_graham_essay.txt', 'file_name': 'paul_graham_essay.txt', 'file_type': 'text/plain', 'file_size': 75042, 'creation_date': '2024-11-07', 'last_modified_date': '2024-11-07'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='dc4b42be-b272-454c-af09-d908f22348e0', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/content/data/paul_graham_essay.txt', 'file_name': 'paul_graham_essay.txt', 'file_type': 'text/plain', 'file_size': 75042, 'creation_date': '2024-11-07', 'last_modified_date': '2024-11-07'}, hash='b0b494aa2d6ee2bb33477b50f0a2016954739ecde1d4ed75eb3419e19f30bb66'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='67f398b2-f4c5-4258-a466-b13208472a68', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': '/content/data/paul_graham_essay.txt', 'file_name': 'paul_graham_essay.txt', 'file_type': 'text/plain', 'file_size': 75042, 'creation_date': '2024-11-07', 'last_modified_date': '2024-11-07'}, hash='a3407741eca36011814d4674af42b151102b8f54799d14552c0541d1fd132327'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='b0ca1e9c-45cd-4afb-a7a6-fa927e3c182d', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='d3ce035da4b2242309b8208638850cce6a2729aa0ad8a7487978b2eb92b00fc7')}, text='Now when I walked past charming little restaurants I could go in and order lunch. It was exciting for a while. Painting started to go better. I experimented with a new kind of still life where I\'d paint one painting in the old way, then photograph it and print it, blown up, on canvas, and then use that as the underpainting for a second still life, painted from the same objects (which hopefully hadn\'t rotted yet).\n\nMeanwhile I looked for an apartment to buy. Now I could actually choose what neighborhood to live in. Where, I asked myself and various real estate agents, is the Cambridge of New York? Aided by occasional visits to actual Cambridge, I gradually realized there wasn\'t one. Huh.\n\nAround this time, in the spring of 2000, I had an idea. It was clear from our experience with Viaweb that web apps were the future. Why not build a web app for making web apps? Why not let people edit code on our server through the browser, and then host the resulting applications for them? [9] You could run all sorts of services on the servers that these applications could use just by making an API call: making and receiving phone calls, manipulating images, taking credit card payments, etc.\n\nI got so excited about this idea that I couldn\'t think about anything else. It seemed obvious that this was the future. I didn\'t particularly want to start another company, but it was clear that this idea would have to be embodied as one, so I decided to move to Cambridge and start it. I hoped to lure Robert into working on it with me, but there I ran into a hitch. Robert was now a postdoc at MIT, and though he\'d made a lot of money the last time I\'d lured him into working on one of my schemes, it had also been a huge time sink. So while he agreed that it sounded like a plausible idea, he firmly refused to work on it.\n\nHmph. Well, I\'d do it myself then. I recruited Dan Giffin, who had worked for Viaweb, and two undergrads who wanted summer jobs, and we got to work trying to build what it\'s now clear is about twenty companies and several open source projects worth of software. The language for defining applications would of course be a dialect of Lisp. But I wasn\'t so naive as to assume I could spring an overt Lisp on a general audience; we\'d hide the parentheses, like Dylan did.\n\nBy then there was a ...
#                        NodeWithScore(node=TextNode(id_='bca19ef1-4e4b-46d0-9a87-a900e65b1898', embedding=None, metadata={'file_path': '/content/data/paul_graham_essay.txt', 'file_name': 'paul_graham_essay.txt', 'file_type': 'text/plain', 'file_size': 75042, 'creation_date': '2024-11-07', 'last_modified_date': '2024-11-07'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='dc4b42be-b272-454c-af09-d908f22348e0', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/content/data/paul_graham_essay.txt', 'file_name': 'paul_graham_essay.txt', 'file_type': 'text/plain', 'file_size': 75042, 'creation_date': '2024-11-07', 'last_modified_date': '2024-11-07'}, hash='b0b494aa2d6ee2bb33477b50f0a2016954739ecde1d4ed75eb3419e19f30bb66'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='b0ca1e9c-45cd-4afb-a7a6-fa927e3c182d', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': '/content/data/paul_graham_essay.txt', 'file_name': 'paul_graham_essay.txt', 'file_type': 'text/plain', 'file_size': 75042, 'creation_date': '2024-11-07', 'last_modified_date': '2024-11-07'}, hash='56b84ace5fb45c1c526386882b557a043d7705655e2baa1aea949be3b362681e'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='e2e5cb7f-8349-4c1f-ae4a-21b94f4e5284', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='31f37f0abb538a24bddcaf3a6a00c280e7af2f1b6e7ec66ae6530581b7384488')}, text='So while working on things that aren\'t prestigious doesn\'t guarantee you\'re on the right track, it at least guarantees you\'re not on the most common type of wrong one.\n\nOver the next several years I wrote lots of essays about all kinds of different topics. O\'Reilly reprinted a collection of them as a book, called Hackers & Painters after one of the essays in it. I also worked on spam filters, and did some more painting. I used to have dinners for a group of friends every thursday night, which taught me how to cook for groups. And I bought another building in Cambridge, a former candy factory (and later, twas said, porn studio), to use as an office.\n\nOne night in October 2003 there was a big party at my house. It was a clever idea of my friend Maria Daniels, who was one of the thursday diners. Three separate hosts would all invite their friends to one party. So for every guest, two thirds of the other guests would be people they didn\'t know but would probably like. One of the guests was someone I didn\'t know but would turn out to like a lot: a woman called Jessica Livingston. A couple days later I asked her out.\n\nJessica was in charge of marketing at a Boston investment bank. This bank thought it understood startups, but over the next year, as she met friends of mine from the startup world, she was surprised how different reality was. And how colorful their stories were. So she decided to compile a book of interviews with startup founders.\n\nWhen the bank had financial problems and she had to fire half her staff, she started looking for a new job. In early 2005 she interviewed for a marketing job at a Boston VC firm. It took them weeks to make up their minds, and during this time I started telling her about all the things that needed to be fixed about venture capital. They should make a larger number of smaller investments instead of a handful of giant ones, they should be funding younger, more technical founders instead of MBAs, they should let the founders remain as CEO, and so on.\n\nOne of my tricks for writing essays had always been to give talks. The prospect of having to stand up in front of a group of people and tell them something that won\'t waste their time is a great spur to the imagination. When the Harvard Computer Society, the undergrad computer club, asked me to g ...
#          metadata={'44a9caee-a671-4859-80d9-78a2aee6063d': {'creation_date': '2024-11-07',
#                                                             'file_name': 'paul_graham_essay.txt',
#                                                             'file_path': '/content/data/paul_graham_essay.txt',
#                                                             'file_size': 75042,
#                                                             'file_type': 'text/plain',
#                                                             'last_modified_date': '2024-11-07'},
#                    'bca19ef1-4e4b-46d0-9a87-a900e65b1898': {'creation_date': '2024-11-07',
#                                                             'file_name': 'paul_graham_essay.txt',
#                                                             'file_path': '/content/data/paul_graham_essay.txt',
#                                                             'file_size': 75042,
#                                                             'file_type': 'text/plain',
#                                                             'last_modified_date': '2024-11-07'}})

# %%
for node in response.source_nodes:
    text_fmt = node.node.get_content().strip().replace("\n", " ")[:200]+"..."
    print(text_fmt)
    print(node.score)
    print("--------")
# Out:
# Now when I walked past charming little restaurants I could go in and order lunch. It was exciting for a while. Painting started to go better. I experimented with a new kind of still life where I'd pai...
# 0.8470505444635096
# --------
# So while working on things that aren't prestigious doesn't guarantee you're on the right track, it at least guarantees you're not on the most common type of wrong one.  Over the next several years I w...
# 0.8406981214404532
# --------

# %% [markdown]
# ### See your results in the Arize UI
# Once you've run a single query, you can see the trace in the Arize UI with each step taken by the retriever, the embedding, and the llm query.
#
# Click through the queries to better understand how the query engine is performing.
#
# Phoenix can be used to understand and troubleshoot your by surfacing:
#  - **Application latency** - highlighting slow invocations of LLMs, Retrievers, etc.
#  - **Token Usage** - Displays the breakdown of token usage with LLMs to surface up your most expensive LLM calls
#  - **Runtime Exceptions** - Critical runtime exceptions such as rate-limiting are captured as exception events.
#  - **Retrieved Documents** - view all the documents retrieved during a retriever call and the score and order in which they were returned
#  - **Embeddings** - view the embedding text used for retrieval and the underlying embedding model
# LLM Parameters - view the parameters used when calling out to an LLM to debug things like temperature and the system prompts
#  - **Prompt Templates** - Figure out what prompt template is used during the prompting step and what variables were used.
#  - **Tool Descriptions** - view the description and function signature of the tools your LLM has been given access to
#  - **LLM Function Calls** - if using OpenAI or other a model with function calls, you can view the function selection and function messages in the input messages to the LLM.
#
# <img src="https://storage.cloud.google.com/arize-assets/tutorials/images/Phoenix-LlamaIndex-Starter.png" width="800"/>

# %% [markdown]
# # Create synthetic dataset of questions
#
# Using the template below, we're going to generate a dataframe of 25 questions we can use to test our customer support agent.

# %%
GEN_TEMPLATE = """
You are an assistant that generates Q&A questions about Paul Graham's essay below.

The questions should involve the essay contents, specific facts and figures,
names, and elements of the story. Do not ask any questions where the answer is
not in the essay contents.

Respond with one question per line. Do not include any numbering at the beginning of each line. Do not include any category headings.
Generate 25 questions. Be sure there are no duplicate questions.

[START ESSAY]
{essay}
[END ESSAY]
"""

with open('data/paul_graham_essay.txt', 'r') as file:
  file_content = file.read()

GEN_TEMPLATE = GEN_TEMPLATE.format(essay=file_content)

# %%
import nest_asyncio
import pandas as pd
nest_asyncio.apply()
from phoenix.evals import OpenAIModel
pd.set_option('display.max_colwidth', 500)

model = OpenAIModel(model="gpt-4o", max_tokens=1300)

# %%
resp = model(GEN_TEMPLATE)

# %%
split_response = resp.strip().split('\n\n')

questions_df = pd.DataFrame(split_response, columns=['input'])
print(questions_df.head(3))
# Out:
#                                                                  input
# 0  What were the two main things Paul Graham worked on before college?
# 1        What type of writing did Paul Graham focus on before college?
# 2        What was the first computer Paul Graham tried programming on?

# %% [markdown]
# Now let's run it and manually inspect the traces! Change the value in `.head(2)` from any number between 1 and 25 to run it on that many data points from the questions we generated earlier.
#
# Then manually inspect the outputs in Phoenix.

# %%
# prompt: apply query_engine.query to every item in questions_df using column 'input'

for index, row in questions_df.iterrows():
    response = query_engine.query(row['input'])
    reference_text = ""
    for node in response.source_nodes:
        reference_text += node.text
        reference_text += "\n"
    questions_df.loc[index, 'output'] = response
    questions_df.loc[index, 'reference'] = reference_text
questions_df.head(3)
# Out:
#                                                                  input  \
# 0  What were the two main things Paul Graham worked on before college?
# 1        What type of writing did Paul Graham focus on before college?
# 2        What was the first computer Paul Graham tried programming on?
#
#                                                                                                                                                output  \
# 0                                                                                                                             Writing and programming
# 1                                                                                        Paul Graham focused on writing short stories before college.
# 2  The first computer Paul Graham tried programming on was the IBM 1401 that his school district used for "data processing" when he was in 9th grade.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              reference
# 0  What I Worked On\n\nFebruary 2021\n\nBefore college the two main things I worked on, outside of school, were writing and programming. I didn't write essays. I wrote what beginning writers were supposed to write then, and probably still are: short stories. My stories were awful. They had hardly any plot, just characters with strong feelings, which I imagined made them deep.\n\nThe first programs I tried writing were on the IBM 1401 that our school district used for what was then called "data ...
# 1  What I Worked On\n\nFebruary 2021\n\nBefore college the two main things I worked on, outside of school, were writing and programming. I didn't write essays. I wrote what beginning writers were supposed to write then, and probably still are: short stories. My stories were awful. They had hardly any plot, just characters with strong feelings, which I imagined made them deep.\n\nThe first programs I tried writing were on the IBM 1401 that our school district used for what was then called "data ...
# 2  What I Worked On\n\nFebruary 2021\n\nBefore college the two main things I worked on, outside of school, were writing and programming. I didn't write essays. I wrote what beginning writers were supposed to write then, and probably still are: short stories. My stories were awful. They had hardly any plot, just characters with strong feelings, which I imagined made them deep.\n\nThe first programs I tried writing were on the IBM 1401 that our school district used for what was then called "data ...

# %% [markdown]
# # Evaluating your RAG app
#
# Now that we have a set of test cases, we can create evaluators to measure performance. This way, we don't have to manually inspect every single trace to see if the LLM is doing the right thing.

# %%
RELEVANCE_EVAL_TEMPLATE = '''You are comparing a reference text to a question and trying to determine if the reference text
contains information relevant to answering the question. Here is the data:
    [BEGIN DATA]
    ************
    [Question]: {input}
    ************
    [Reference text]: {reference}
    [END DATA]

Compare the Question above to the Reference text. You must determine whether the Reference text
contains information that can answer the Question. Please focus on whether the very specific
question can be answered by the information in the Reference text.
Your response must be single word, either "relevant" or "unrelated",
and should not contain any text or characters aside from that word.
"unrelated" means that the reference text does not contain an answer to the Question.
"relevant" means the reference text contains an answer to the Question.
'''

CORRECTNESS_EVAL_TEMPLATE = '''You are given a question, an answer and reference text. You must determine whether the
given answer correctly answers the question based on the reference text. Here is the data:
    [BEGIN DATA]
    ************
    [Question]: {input}
    ************
    [Reference]: {reference}
    ************
    [Answer]: {output}
    [END DATA]
Your response must be a single word, either "correct" or "incorrect",
and should not contain any text or characters aside from that word.
"correct" means that the question is correctly and fully answered by the answer.
"incorrect" means that the question is not correctly or only partially answered by the
answer.
'''

# %% [markdown]
# We will be creating an LLM as a judge using the prompt templates above by taking the spans recorded by Phoenix, and then giving them labels using the `llm_classify` function. This function uses LLMs to evaluate your LLM calls and gives them labels and explanations. You can read more detail [here](https://docs.arize.com/phoenix/api/evals#phoenix.evals.llm_classify).
#
# To get the spans in the right format, we'll be using our helper function `get_qa_with_reference`. You can see how this function works [here](https://docs.arize.com/phoenix/tracing/how-to-tracing/extract-data-from-spans#pre-defined-queries) and the github reference [here](https://github.com/Arize-ai/phoenix/blob/main/src/phoenix/trace/dsl/helpers.py#L71).

# %%
from phoenix.evals import (
    OpenAIModel,
    llm_classify
)

RELEVANCE_RAILS = ["relevant", "unrelated"]
CORRECTNESS_RAILS = ["incorrect", "correct"]

relevance_eval_df = llm_classify(
    dataframe=questions_df,
    template=RELEVANCE_EVAL_TEMPLATE,
    model=OpenAIModel(model='gpt-4o'),
    rails=RELEVANCE_RAILS,
    provide_explanation=True,
    include_prompt=True,
    concurrency=4
)

correctness_eval_df = llm_classify(
    dataframe=questions_df,
    template=CORRECTNESS_EVAL_TEMPLATE,
    model=OpenAIModel(model='gpt-4o'),
    rails=CORRECTNESS_RAILS,
    provide_explanation=True,
    include_prompt=True,
    concurrency=4
)
# Out:
# llm_classify |          | 0/26 (0.0%) | ⏳ 00:00<? | ?it/s
# llm_classify |          | 0/26 (0.0%) | ⏳ 00:00<? | ?it/s

# %% [markdown]
# Let's look at and inspect the results of our evaluatiion!

# %%
relevance_eval_df
# Out:
#         label  \
# 0    relevant
# 1    relevant
# 2    relevant
# 3    relevant
# 4    relevant
# 5    relevant
# 6    relevant
# 7    relevant
# 8    relevant
# 9    relevant
# 10   relevant
# 11   relevant
# 12   relevant
# 13   relevant
# 14  unrelated
# 15  unrelated
# 16  unrelated
# 17  unrelated
# 18   relevant
# 19   relevant
# 20   relevant
# 21  unrelated
# 22  unrelated
# 23  unrelated
# 24  unrelated
# 25  unrelated
#
#                                                                                                                                                                                                                                                                                                                                                                                                      explanation  \
# 0                                                                                                                                       The reference text explicitly states that before college, Paul Graham worked on writing and programming. These are identified as the two main things he worked on outside of school. This directly answers the question about what Paul Graham worked on before college.
# 1                                                                                                                                                                  The reference text explicitly mentions that before college, Paul Graham focused on writing short stories and programming. This directly answers the question about the type of writing he focused on before college, which was short stories.
# 2                                                                                                                                                         The reference text mentions that the first computer Paul Graham tried programming on was the IBM 1401, which was used by his school district for data processing. This directly answers the question about the first computer he tried programming on.
# 3                                                                                                                                                                            The reference text mentions that Paul Graham and his friend Rich Draves got permission to use the IBM 1401. This directly answers the question about who Paul Graham's friend was that got permission to use the IBM 1401 with him.
# 4                                                                                                                                                                                                         The reference text mentions that Paul Graham used an early version of Fortran to program on the IBM 1401. This directly answers the question about which programming language he used on that machine.
# 5                                                                                                                                                                 The reference text mentions that the first of Paul Graham's friends to get a microcomputer built it himself from a kit sold by Heathkit. This directly answers the question about what was the first microcomputer Paul Graham's friend built.
# 6                                                                                                                                                                                       The reference text mentions that Paul Graham's father eventually bought him a TRS-80 computer after years of nagging. This directly answers the question about the type of computer Paul Graham's father bought for him.
# 7                                                                                                                                                                            The reference text mentions that Paul Graham wrote a word processor that his father used to write at least one book. This directly answers the question about which program Paul Graham wrote that his father used to write a book.
# 8                                                                                                                                                                                                                   The reference text explicitly states that Paul Graham initially planned to study philosophy in college. This directly answers the question about what subject he initially planned to study.
# 9                                                                                                                                                          The reference text explicitly mentions that Paul Graham's interest in AI was influenced by a novel by Heinlein called "The Moon is a Harsh Mistress." This directly answers the question about which novel by Heinlein influenced his interest in AI.
# 10                                                                                                                                                                                            The reference text explicitly mentions that the intelligent computer in "The Moon is a Harsh Mistress" is called Mike. This directly answers the question about the name of the intelligent computer in the novel.
# 11                                                                                                                                                            The reference text explicitly mentions a PBS documentary that showed Terry Winograd using SHRDLU as one of the influences on Paul Graham's interest in AI. This directly answers the question about which PBS documentary influenced his interest.
# 12                                                                                                                                                                                                                 The reference text mentions that Terry Winograd demonstrated an AI program called SHRDLU. This directly answers the question about the name of the AI program demonstrated by Terry Winograd.
# 13                                                                                                                                                                                 The reference text mentions that Paul Graham learned Lisp to teach himself AI, as Lisp was regarded as the language of AI at the time. This directly answers the question about which programming language he learned for AI.
# 14                                                                                                             The reference text does not mention Cornell or the default programming language used there when Paul Graham was a student. It discusses various topics related to Paul Graham's experiences and projects, but none of them are about his time at Cornell or the programming languages used there.
# 15                                                                                                        The reference text does not mention anything about Paul Graham's undergraduate thesis or its topic. It discusses his work on Lisp, his experiences with publishing essays online, and his involvement with various projects and companies, but there is no information about his undergraduate thesis.
# 16                                                                                     The reference text does not mention any specific grad schools that Paul Graham applied to. It discusses his experiences with art schools and his career, but does not provide information about grad schools. Therefore, the reference text is unrelated to the question about which grad schools Paul Graham applied to.
# 17                                                                                                                                                                                       The reference text does not mention which grad school accepted Paul Graham. It discusses his experiences in grad school and his applications to art schools, but it does not specify the grad school that accepted him.
# 18  The reference text contains a detailed account of Paul Graham's realization during his first year of grad school that AI, as practiced at the time, was a hoax. He realized that the approach of translating natural language into formal representations was fundamentally flawed and would not lead to true understanding of natural language. This realization is directly related to the question asked.
# 19                                                                                                                                                                               The reference text explicitly mentions that Paul Graham decided to write a book about Lisp hacking and that the book is titled 'On Lisp'. This directly answers the question about which book he decided to write on the topic.
# 20                                                                                                                               The reference text mentions an 'uneasy alliance' in Computer Science between theory and systems, where theory people prove things and systems people build things. This directly answers the question about the uneasy alliance in Computer Science that Paul Graham mentioned.
# 21                                                                 The reference text discusses Paul Graham's various projects and ideas, including his work on web applications, Lisp, and painting. However, it does not explicitly mention what he wanted to build that would last. The text focuses more on his activities and thoughts at different times rather than a specific enduring goal or creation.
# 22                                           The reference text does not mention anything about Paul Graham visiting Rich Draves in 1988 or any location related to such a visit. The text primarily discusses Paul Graham's experiences with Viaweb, his thoughts on web applications, and his life changes after selling Viaweb, but it does not provide any information about a visit to Rich Draves in 1988.
# 23                                                                                                                                    The reference text does not mention Paul Graham visiting the Carnegie Institute or any realization he had there. It discusses his experiences with web apps, starting a company, and his involvement with Y Combinator, but there is no mention of the Carnegie Institute.
# 24                                                                                                                                                                                                    The reference text does not mention Paul Graham taking any classes at Harvard. It discusses various activities and events in his life, but there is no information about him attending classes at Harvard.
# 25                                                                                                                                               The reference text does not mention any program at Cornell that allowed Paul Graham to choose his own major. It primarily discusses his experiences with Y Combinator, his personal life, and his time at art schools, but not his academic program at Cornell.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  prompt  \
# 0   You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What were the two main things Paul Graham worked on before college?\n    ************\n    [Reference text]: What I Worked On\n\nFebruary 2021\n\nBefore college the two main things I worked on, outside of school, were writing and programming. I didn't write essays. I wrot...
# 1   You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What type of writing did Paul Graham focus on before college?\n    ************\n    [Reference text]: What I Worked On\n\nFebruary 2021\n\nBefore college the two main things I worked on, outside of school, were writing and programming. I didn't write essays. I wrote what...
# 2   You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What was the first computer Paul Graham tried programming on?\n    ************\n    [Reference text]: What I Worked On\n\nFebruary 2021\n\nBefore college the two main things I worked on, outside of school, were writing and programming. I didn't write essays. I wrote what...
# 3   You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: Who was Paul Graham's friend that got permission to use the IBM 1401 with him?\n    ************\n    [Reference text]: What I Worked On\n\nFebruary 2021\n\nBefore college the two main things I worked on, outside of school, were writing and programming. I didn't write ess...
# 4   You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What programming language did Paul Graham use on the IBM 1401?\n    ************\n    [Reference text]: What I Worked On\n\nFebruary 2021\n\nBefore college the two main things I worked on, outside of school, were writing and programming. I didn't write essays. I wrote wha...
# 5   You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What was the first microcomputer Paul Graham's friend built?\n    ************\n    [Reference text]: What I Worked On\n\nFebruary 2021\n\nBefore college the two main things I worked on, outside of school, were writing and programming. I didn't write essays. I wrote what ...
# 6   You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What type of computer did Paul Graham's father eventually buy for him?\n    ************\n    [Reference text]: What I Worked On\n\nFebruary 2021\n\nBefore college the two main things I worked on, outside of school, were writing and programming. I didn't write essays. I w...
# 7   You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What program did Paul Graham write that his father used to write a book?\n    ************\n    [Reference text]: What I Worked On\n\nFebruary 2021\n\nBefore college the two main things I worked on, outside of school, were writing and programming. I didn't write essays. I...
# 8   You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What subject did Paul Graham initially plan to study in college?\n    ************\n    [Reference text]: What I Worked On\n\nFebruary 2021\n\nBefore college the two main things I worked on, outside of school, were writing and programming. I didn't write essays. I wrote w...
# 9   You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: Which novel by Heinlein influenced Paul Graham's interest in AI?\n    ************\n    [Reference text]: I couldn't have put this into words when I was 18. All I knew at the time was that I kept taking philosophy courses and they kept being boring. So I decided to switch...
# 10  You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What was the name of the intelligent computer in "The Moon is a Harsh Mistress"?\n    ************\n    [Reference text]: I couldn't have put this into words when I was 18. All I knew at the time was that I kept taking philosophy courses and they kept being boring. So I d...
# 11  You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What PBS documentary influenced Paul Graham's interest in AI?\n    ************\n    [Reference text]: I couldn't have put this into words when I was 18. All I knew at the time was that I kept taking philosophy courses and they kept being boring. So I decided to switch to...
# 12  You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What was the name of the AI program demonstrated by Terry Winograd?\n    ************\n    [Reference text]: I couldn't have put this into words when I was 18. All I knew at the time was that I kept taking philosophy courses and they kept being boring. So I decided to swi...
# 13  You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What programming language did Paul Graham learn to teach himself AI?\n    ************\n    [Reference text]: I couldn't have put this into words when I was 18. All I knew at the time was that I kept taking philosophy courses and they kept being boring. So I decided to sw...
# 14  You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What was the default programming language at Cornell when Paul Graham was there?\n    ************\n    [Reference text]: Now when I walked past charming little restaurants I could go in and order lunch. It was exciting for a while. Painting started to go better. I experi...
# 15  You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What was the topic of Paul Graham's undergraduate thesis?\n    ************\n    [Reference text]: A lot of Lisp hackers dream of building a new Lisp, partly because one of the distinctive features of the language is that it has dialects, and partly, I think, because we h...
# 16  You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: Which three grad schools did Paul Graham apply to?\n    ************\n    [Reference text]: I didn't want to drop out of grad school, but how else was I going to get out? I remember when my friend Robert Morris got kicked out of Cornell for writing the internet worm of 19...
# 17  You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: Which grad school accepted Paul Graham?\n    ************\n    [Reference text]: I didn't want to drop out of grad school, but how else was I going to get out? I remember when my friend Robert Morris got kicked out of Cornell for writing the internet worm of 1988, I was e...
# 18  You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What realization did Paul Graham have about AI during his first year of grad school?\n    ************\n    [Reference text]: I couldn't have put this into words when I was 18. All I knew at the time was that I kept taking philosophy courses and they kept being boring. So...
# 19  You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What book did Paul Graham decide to write about Lisp hacking?\n    ************\n    [Reference text]: So I looked around to see what I could salvage from the wreckage of my plans, and there was Lisp. I knew from experience that Lisp was interesting for its own sake and n...
# 20  You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What was the uneasy alliance in Computer Science that Paul Graham mentioned?\n    ************\n    [Reference text]: So I looked around to see what I could salvage from the wreckage of my plans, and there was Lisp. I knew from experience that Lisp was interesting for its...
# 21  You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What did Paul Graham want to build that would last?\n    ************\n    [Reference text]: Now when I walked past charming little restaurants I could go in and order lunch. It was exciting for a while. Painting started to go better. I experimented with a new kind of sti...
# 22  You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: Where did Paul Graham go to visit Rich Draves in 1988?\n    ************\n    [Reference text]: Now when I walked past charming little restaurants I could go in and order lunch. It was exciting for a while. Painting started to go better. I experimented with a new kind of ...
# 23  You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What realization did Paul Graham have while visiting the Carnegie Institute?\n    ************\n    [Reference text]: Now when I walked past charming little restaurants I could go in and order lunch. It was exciting for a while. Painting started to go better. I experiment...
# 24  You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What type of classes did Paul Graham start taking at Harvard?\n    ************\n    [Reference text]: So while working on things that aren't prestigious doesn't guarantee you're on the right track, it at least guarantees you're not on the most common type of wrong one.\n...
# 25  You are comparing a reference text to a question and trying to determine if the reference text\ncontains information relevant to answering the question. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What was the name of the program at Cornell that allowed Paul Graham to choose his own major?\n    ************\n    [Reference text]: So if Sam said yes, we'd let him reorganize YC. Robert and I would retire, and Jessica and Trevor would become ordinary partners.\n\nWhen...
#
#    exceptions execution_status  execution_seconds
# 0          []        COMPLETED           1.225341
# 1          []        COMPLETED           1.319833
# 2          []        COMPLETED           1.400230
# 3          []        COMPLETED           2.072494
# 4          []        COMPLETED           1.164307
# 5          []        COMPLETED           1.491344
# 6          []        COMPLETED           1.535304
# 7          []        COMPLETED           1.235477
# 8          []        COMPLETED           0.850536
# 9          []        COMPLETED           1.180476
# 10         []        COMPLETED           0.882563
# 11         []        COMPLETED           0.897981
# 12         []        COMPLETED           1.596846
# 13         []        COMPLETED           1.118300
# 14         []        COMPLETED           1.725329
# 15         []        COMPLETED           1.646416
# 16         []        COMPLETED           1.285162
# 17         []        COMPLETED           2.094229
# 18         []        COMPLETED           1.879365
# 19         []        COMPLETED           1.842192
# 20         []        COMPLETED           1.310702
# 21         []        COMPLETED           1.243440
# 22         []        COMPLETED           2.056958
# 23         []        COMPLETED           1.146099
# 24         []        COMPLETED           1.240945
# 25         []        COMPLETED           2.332154

# %%
correctness_eval_df
# Out:
#         label  \
# 0     correct
# 1     correct
# 2     correct
# 3     correct
# 4     correct
# 5     correct
# 6     correct
# 7     correct
# 8     correct
# 9     correct
# 10    correct
# 11    correct
# 12    correct
# 13    correct
# 14  incorrect
# 15  incorrect
# 16  incorrect
# 17  incorrect
# 18    correct
# 19    correct
# 20    correct
# 21    correct
# 22  incorrect
# 23  incorrect
# 24  incorrect
# 25  incorrect
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             explanation  \
# 0                                                                                                                                                                                                                                                               The reference text states that before college, the two main things Paul Graham worked on, outside of school, were writing and programming. The answer provided is 'Writing and programming,' which matches the information given in the reference text.
# 1                                                                                                                                                                                                                                                                                   The reference text states that before college, Paul Graham worked on writing short stories. The answer provided is consistent with this information, as it states that Paul Graham focused on writing short stories before college.
# 2                                                                                                                                                                                                                                                                       The reference text states that the first computer Paul Graham tried programming on was the IBM 1401, which was used by his school district for "data processing" when he was in 9th grade. This matches the information provided in the answer.
# 3                                                                                                                                                                                                                                                                              The reference text states that Paul Graham and his friend Rich Draves got permission to use the IBM 1401. Therefore, the answer 'Rich Draves' correctly identifies Paul Graham's friend who got permission to use the IBM 1401 with him.
# 4                                                                                                                                                                                                                                                                                                                             The reference text states that Paul Graham used an early version of Fortran on the IBM 1401. The answer provided is 'Fortran', which matches the information given in the reference text.
# 5                                                                                                                                                                                                                                                                                                                              The reference text states that the first microcomputer Paul Graham's friend built was sold as a kit by Heathkit. This matches the information provided in the answer, making it correct.
# 6                                                                                                                                                                                                                                                                                                        The reference text states that after years of nagging, Paul Graham's father bought him a TRS-80 computer. This directly answers the question about what type of computer his father eventually bought for him.
# 7                                                                                                                                                                                                                                                 The reference text states that Paul Graham wrote a word processor that his father used to write at least one book. Therefore, the answer 'A word processor' correctly answers the question about what program Paul Graham wrote that his father used to write a book.
# 8                                                                                                                                                                                                                                                                                                                                                         The reference text states that Paul Graham initially planned to study philosophy in college. The answer provided matches this information, making it correct.
# 9                                                                                                                                                                                                                                                                                                                The reference text explicitly states that the novel by Heinlein that influenced Paul Graham's interest in AI was "The Moon is a Harsh Mistress." The answer provided matches this information exactly.
# 10                                                                                                                                                                                                                                                                                                            The reference text explicitly states that the intelligent computer in "The Moon is a Harsh Mistress" is called Mike. The answer provided is "Mike," which matches the information given in the reference.
# 11                                                                                                                                                                                                                                                                                           The reference text explicitly states that a PBS documentary showing Terry Winograd using SHRDLU was one of the two main influences on Paul Graham's interest in AI. The answer provided matches this information directly.
# 12                                                                                                                                                                                                                                                                                                                          The reference text clearly states that Terry Winograd demonstrated an AI program called SHRDLU. The answer provided is "SHRDLU," which matches the information given in the reference text.
# 13                                                                                                                                                                                                                                                                                                                 The reference text states that Paul Graham learned Lisp to teach himself AI. The answer provided matches this information, correctly identifying Lisp as the programming language he learned for AI.
# 14                                                                                                                                                                                                                        The reference text does not mention what the default programming language at Cornell was when Paul Graham was there. It discusses Lisp in the context of Paul Graham's later work and interests, but it does not specify that Lisp was the default language at Cornell during his time there.
# 15                                                                                                                                                                                                                                                                 The reference text does not mention anything about Paul Graham's undergraduate thesis topic. It discusses various aspects of his career and projects, but there is no information about his undergraduate thesis, let alone it being about painting.
# 16                                                                      The reference text does not mention Paul Graham applying to any grad schools. It only mentions him applying to art schools: RISD in the US and the Accademia di Belli Arti in Florence. The answer incorrectly assumes that the unnamed grad school he was attending before deciding to drop out was one he applied to, but the question specifically asks for grad schools he applied to, not art schools or the one he was already attending.
# 17                                                                                                                                                                                                                            The reference text states that RISD (Rhode Island School of Design) accepted Paul Graham for art school, not grad school. The question specifically asks about grad school, and the reference does not mention any grad school accepting Paul Graham. Therefore, the answer is incorrect.
# 18  The reference text states that during his first year of grad school, Paul Graham realized that AI, as practiced at the time, was a hoax. This realization was based on the understanding that the AI methods used then, which involved translating sentences into formal representations, were not capable of truly understanding natural language. The answer provided states that Paul Graham realized the type of AI being practiced was not effective, which aligns with the realization described in the re...
# 19                                                                                                                                                                                                                                                        The reference text states that Paul Graham decided to write a book about Lisp hacking and that the book is called 'On Lisp.' Therefore, the answer 'On Lisp' correctly answers the question about which book Paul Graham decided to write about Lisp hacking.
# 20                                                                                                                                                                                                                                                                                                                                   The reference text explicitly states that the uneasy alliance in Computer Science is between two halves: theory and systems. The answer provided matches this information exactly.
# 21                                                                                                                                                                                                                                          The reference text indicates that Paul Graham wanted to build a new Lisp that would last. He was motivated by the idea of creating a new dialect of Lisp, which he called Arc, and he wanted it to be a lasting contribution. The answer correctly captures this intention.
# 22                                                                                                                                                                                                     The reference text does not mention Paul Graham visiting Rich Draves in Cambridge in 1988. It discusses various events in Paul Graham's life, including his time in Cambridge, but there is no specific mention of a visit to Rich Draves in 1988. Therefore, the answer is not supported by the reference text.
# 23                                                                                        The question asks about a realization Paul Graham had while visiting the Carnegie Institute. The reference text mentions that Paul Graham realized there wasn't a neighborhood in New York equivalent to Cambridge, but this realization is not directly linked to visiting the Carnegie Institute. The reference text does not mention the Carnegie Institute at all, so the answer does not correctly address the question.
# 24                                                                                                                                                                                                                                                                                  The reference text does not mention Paul Graham taking painting classes at Harvard. It mentions that he did some painting, but there is no indication that he took painting classes at Harvard. Therefore, the answer is incorrect.
# 25                                                                                                                                                                                                                                                                  The reference text does not mention a program at Cornell that allowed Paul Graham to choose his own major. The BFA program mentioned in the answer is related to RISD, not Cornell. Therefore, the answer is incorrect based on the reference text.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  prompt  \
# 0   You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What were the two main things Paul Graham worked on before college?\n    ************\n    [Reference]: What I Worked On\n\nFebruary 2021\n\nBefore college the two main things I worked on, outside of school, were writing and programming. I didn't write essays. I w...
# 1   You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What type of writing did Paul Graham focus on before college?\n    ************\n    [Reference]: What I Worked On\n\nFebruary 2021\n\nBefore college the two main things I worked on, outside of school, were writing and programming. I didn't write essays. I wrote w...
# 2   You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What was the first computer Paul Graham tried programming on?\n    ************\n    [Reference]: What I Worked On\n\nFebruary 2021\n\nBefore college the two main things I worked on, outside of school, were writing and programming. I didn't write essays. I wrote w...
# 3   You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: Who was Paul Graham's friend that got permission to use the IBM 1401 with him?\n    ************\n    [Reference]: What I Worked On\n\nFebruary 2021\n\nBefore college the two main things I worked on, outside of school, were writing and programming. I didn't write ...
# 4   You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What programming language did Paul Graham use on the IBM 1401?\n    ************\n    [Reference]: What I Worked On\n\nFebruary 2021\n\nBefore college the two main things I worked on, outside of school, were writing and programming. I didn't write essays. I wrote ...
# 5   You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What was the first microcomputer Paul Graham's friend built?\n    ************\n    [Reference]: What I Worked On\n\nFebruary 2021\n\nBefore college the two main things I worked on, outside of school, were writing and programming. I didn't write essays. I wrote wh...
# 6   You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What type of computer did Paul Graham's father eventually buy for him?\n    ************\n    [Reference]: What I Worked On\n\nFebruary 2021\n\nBefore college the two main things I worked on, outside of school, were writing and programming. I didn't write essays. ...
# 7   You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What program did Paul Graham write that his father used to write a book?\n    ************\n    [Reference]: What I Worked On\n\nFebruary 2021\n\nBefore college the two main things I worked on, outside of school, were writing and programming. I didn't write essays...
# 8   You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What subject did Paul Graham initially plan to study in college?\n    ************\n    [Reference]: What I Worked On\n\nFebruary 2021\n\nBefore college the two main things I worked on, outside of school, were writing and programming. I didn't write essays. I wrot...
# 9   You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: Which novel by Heinlein influenced Paul Graham's interest in AI?\n    ************\n    [Reference]: I couldn't have put this into words when I was 18. All I knew at the time was that I kept taking philosophy courses and they kept being boring. So I decided to swi...
# 10  You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What was the name of the intelligent computer in "The Moon is a Harsh Mistress"?\n    ************\n    [Reference]: I couldn't have put this into words when I was 18. All I knew at the time was that I kept taking philosophy courses and they kept being boring. So ...
# 11  You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What PBS documentary influenced Paul Graham's interest in AI?\n    ************\n    [Reference]: I couldn't have put this into words when I was 18. All I knew at the time was that I kept taking philosophy courses and they kept being boring. So I decided to switch...
# 12  You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What was the name of the AI program demonstrated by Terry Winograd?\n    ************\n    [Reference]: I couldn't have put this into words when I was 18. All I knew at the time was that I kept taking philosophy courses and they kept being boring. So I decided to ...
# 13  You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What programming language did Paul Graham learn to teach himself AI?\n    ************\n    [Reference]: I couldn't have put this into words when I was 18. All I knew at the time was that I kept taking philosophy courses and they kept being boring. So I decided to...
# 14  You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What was the default programming language at Cornell when Paul Graham was there?\n    ************\n    [Reference]: Now when I walked past charming little restaurants I could go in and order lunch. It was exciting for a while. Painting started to go better. I exp...
# 15  You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What was the topic of Paul Graham's undergraduate thesis?\n    ************\n    [Reference]: A lot of Lisp hackers dream of building a new Lisp, partly because one of the distinctive features of the language is that it has dialects, and partly, I think, because w...
# 16  You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: Which three grad schools did Paul Graham apply to?\n    ************\n    [Reference]: I didn't want to drop out of grad school, but how else was I going to get out? I remember when my friend Robert Morris got kicked out of Cornell for writing the internet worm of...
# 17  You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: Which grad school accepted Paul Graham?\n    ************\n    [Reference]: I didn't want to drop out of grad school, but how else was I going to get out? I remember when my friend Robert Morris got kicked out of Cornell for writing the internet worm of 1988, I wa...
# 18  You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What realization did Paul Graham have about AI during his first year of grad school?\n    ************\n    [Reference]: I couldn't have put this into words when I was 18. All I knew at the time was that I kept taking philosophy courses and they kept being boring....
# 19  You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What book did Paul Graham decide to write about Lisp hacking?\n    ************\n    [Reference]: So I looked around to see what I could salvage from the wreckage of my plans, and there was Lisp. I knew from experience that Lisp was interesting for its own sake an...
# 20  You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What was the uneasy alliance in Computer Science that Paul Graham mentioned?\n    ************\n    [Reference]: So I looked around to see what I could salvage from the wreckage of my plans, and there was Lisp. I knew from experience that Lisp was interesting for ...
# 21  You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What did Paul Graham want to build that would last?\n    ************\n    [Reference]: Now when I walked past charming little restaurants I could go in and order lunch. It was exciting for a while. Painting started to go better. I experimented with a new kind of ...
# 22  You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: Where did Paul Graham go to visit Rich Draves in 1988?\n    ************\n    [Reference]: Now when I walked past charming little restaurants I could go in and order lunch. It was exciting for a while. Painting started to go better. I experimented with a new kind ...
# 23  You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What realization did Paul Graham have while visiting the Carnegie Institute?\n    ************\n    [Reference]: Now when I walked past charming little restaurants I could go in and order lunch. It was exciting for a while. Painting started to go better. I experim...
# 24  You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What type of classes did Paul Graham start taking at Harvard?\n    ************\n    [Reference]: So while working on things that aren't prestigious doesn't guarantee you're on the right track, it at least guarantees you're not on the most common type of wrong one...
# 25  You are given a question, an answer and reference text. You must determine whether the\ngiven answer correctly answers the question based on the reference text. Here is the data:\n    [BEGIN DATA]\n    ************\n    [Question]: What was the name of the program at Cornell that allowed Paul Graham to choose his own major?\n    ************\n    [Reference]: So if Sam said yes, we'd let him reorganize YC. Robert and I would retire, and Jessica and Trevor would become ordinary partners.\n\nW...
#
#    exceptions execution_status  execution_seconds
# 0          []        COMPLETED           1.416222
# 1          []        COMPLETED           1.230546
# 2          []        COMPLETED           1.377718
# 3          []        COMPLETED           1.596712
# 4          []        COMPLETED           1.885585
# 5          []        COMPLETED           1.411798
# 6          []        COMPLETED           1.832405
# 7          []        COMPLETED           1.240479
# 8          []        COMPLETED           1.037174
# 9          []        COMPLETED           1.187599
# 10         []        COMPLETED           0.839768
# 11         []        COMPLETED           1.481567
# 12         []        COMPLETED           1.429905
# 13         []        COMPLETED           1.459072
# 14         []        COMPLETED           1.364107
# 15         []        COMPLETED           1.425108
# 16         []        COMPLETED           1.684167
# 17         []        COMPLETED           5.040676
# 18         []        COMPLETED           1.870083
# 19         []        COMPLETED           2.124646
# 20         []        COMPLETED           0.905761
# 21         []        COMPLETED           2.057052
# 22         []        COMPLETED           1.447731
# 23         []        COMPLETED           2.250577
# 24         []        COMPLETED           1.131635
# 25         []        COMPLETED           1.456183
